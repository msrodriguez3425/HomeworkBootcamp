# %%
#Import dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

#Read in csv file and create dataframe
csv_file = "../Resources/winemag-data-130k-v3.csv"
wine_csv_df = pd.read_csv(csv_file,encoding = "UTF-8")

#Drop region_2 column
wine_csv_df = wine_csv_df.drop(columns="region_2")

#Read in json file and create dataframe
json_file ="../Resources/winemag-data-130k-v3.json"
wine_json_df = pd.read_json(json_file)
wine_json_df.head()

#Merge csv and json dataframes
complete_wine_df = pd.merge(wine_json_df, wine_csv_df, on = "title")

#Drop rows containing null values
complete_wine_df = complete_wine_df.dropna()

#Reset index so that we have an "index" column that we can manipulate numerically
complete_wine_df = complete_wine_df.reset_index(drop=True).reset_index()

#Add one to each value in the "index" column (indices must start at 1 in pgAdmin)
complete_wine_df["index"] += 1

complete_wine_df.head()
# Out:
#    index                                              title  \
# 0      1  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 1      2  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 2      3  Henriet-Bazin NV Blanc de Noirs Grand Cru Brut...
# 3      4  Henriet-Bazin NV Blanc de Noirs Grand Cru Brut...
# 4      5  Henriet-Bazin NV Blanc de Noirs Grand Cru Brut...
#
#                                          description  \
# 0  Soft, supple plum envelopes an oaky structure ...
# 1  Soft, supple plum envelopes an oaky structure ...
# 2  From Verzenay on the Montagne de Reims this wi...
# 3  From Verzenay on the Montagne de Reims this wi...
# 4  From Verzenay on the Montagne de Reims this wi...
#
#                      designation  points  price     taster_name  \
# 0                 Mountain Cuvée      87   19.0  Virginie Boone
# 1                 Mountain Cuvée      87   19.0  Virginie Boone
# 2  Blanc de Noirs Grand Cru Brut      91   68.0      Roger Voss
# 3  Blanc de Noirs Grand Cru Brut      91   68.0      Roger Voss
# 4  Blanc de Noirs Grand Cru Brut      91   68.0      Roger Voss
#
#   taster_twitter_handle country    province     region_1             variety  \
# 0               @vboone      US  California  Napa Valley  Cabernet Sauvignon
# 1               @vboone      US  California  Napa Valley  Cabernet Sauvignon
# 2            @vossroger  France   Champagne    Champagne          Pinot Noir
# 3            @vossroger  France   Champagne    Champagne          Pinot Noir
# 4            @vossroger  France   Champagne    Champagne          Pinot Noir
#
#                winery
# 0  Kirkland Signature
# 1  Kirkland Signature
# 2       Henriet-Bazin
# 3       Henriet-Bazin
# 4       Henriet-Bazin

# %%
rds_connection_string = 'postgres:@localhost:5432/wine_db'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
complete_wine_df.to_sql(name = "complete_wine", con = engine, if_exists = "append",index = False)
